# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Read the dataset for churn

# %%
ds = pd.read_csv("C:/Users/Olena/Desktop/ITSS/files/variant_4.csv")

# %%
for col in ds.columns:
    if ds[col].isnull().values.any():
        print("Missing data in ", col)

missing = list()
for x in ds.columns:
    if ds[x].isnull().sum() != 0:
        print(x, ds[x].isnull().sum())
        missing.append(x)
# Out:
# Missing data in  Course
# Missing data in  Daytime/evening attendance
# Missing data in  Previous qualification
# Missing data in  Previous qualification (grade)
# Missing data in  Mother's occupation
# Missing data in  Father's occupation
# Missing data in  International
# Missing data in  Curricular units 1st sem (enrolled)
# Missing data in  Curricular units 1st sem (approved)
# Missing data in  Curricular units 1st sem (grade)
# Missing data in  Curricular units 1st sem (without evaluations)
# Missing data in  Curricular units 2nd sem (credited)
# Missing data in  Curricular units 2nd sem (enrolled)
# Missing data in  Curricular units 2nd sem (evaluations)
# Missing data in  Curricular units 2nd sem (grade)
# Missing data in  Inflation rate
# Missing data in  Citizenship
# Missing data in  Family Position
# Missing data in  Special Needs
# Course 221
# Daytime/evening attendance	 110
# Previous qualification 221
# Previous qualification (grade) 2323
# Mother's occupation 221
# Father's occupation 110
# International 325
# Curricular units 1st sem (enrolled) 221
# Curricular units 1st sem (approved) 221
# Curricular units 1st sem (grade) 435
# Curricular units 1st sem (without evaluations) 2212
# Curricular units 2nd sem (credited) 221
# Curricular units 2nd sem (enrolled) 110
# Curricular units 2nd sem (evaluations) 110
# Curricular units 2nd sem (grade) 110
# Inflation rate 110
# Citizenship 465
# Family Position 2323
# Special Needs 2212

# %% [markdown]
# ## Data engineering

# %% [markdown]
# #### Missing data imputation

# %%
mean_impute_columns = [
       'Admission grade',
       'Previous qualification',
       'Previous qualification (grade)',
       'Curricular units 1st sem (enrolled)',
       'Curricular units 1st sem (evaluations)',
       'Curricular units 1st sem (approved)',
       'Curricular units 1st sem (grade)',
       'Curricular units 1st sem (without evaluations)',
       'Curricular units 2nd sem (credited)',
       'Curricular units 2nd sem (enrolled)',
       'Curricular units 2nd sem (evaluations)',
       'Curricular units 2nd sem (approved)',
       'Curricular units 2nd sem (grade)',
       'Curricular units 2nd sem (without evaluations)',
       'Inflation rate', 'GDP']
mode_impute_columns = ['Unemployment rate']

# %%
def impute_na(df, variable, value):

    return df[variable].fillna(value)

# %%
# Let's create a dict of mean values

mean_impute_values = dict()
for column in mean_impute_columns:
    mean_impute_values[column] = ds[column].mean()
print(mean_impute_values)
# Out:
# {'Admission grade': 126.97811934900544, 'Previous qualification': 4.6302640970735185, 'Previous qualification (grade)': 132.57405997144215, 'Curricular units 1st sem (enrolled)': 6.285986200333095, 'Curricular units 1st sem (evaluations)': 8.299050632911392, 'Curricular units 1st sem (approved)': 4.696883178681894, 'Curricular units 1st sem (grade)': 10.635909431107466, 'Curricular units 1st sem (without evaluations)': 0.13517179023508138, 'Curricular units 2nd sem (credited)': 0.549845348560552, 'Curricular units 2nd sem (enrolled)': 6.2373667130273525, 'Curricular units 2nd sem (evaluations)': 8.061196105702365, 'Curricular units 2nd sem (approved)': 4.435804701627487, 'Curricular units 2nd sem (grade)': 10.232829111546907, 'Curricular units 2nd sem (without evaluations)': 0.15031645569620253, 'Inflation rate': 1.2293694946685212, 'GDP': 0.001968806509945778}

# %%
for column in mean_impute_columns:
    ds[column] = impute_na(ds, column, mean_impute_values[column])

# %%
# Let's create a dict of mode values

mode_impute_values = dict()
for column in mode_impute_columns:
    mode_impute_values[column] = ds[column].mode()[0]
print(mode_impute_values)
# Out:
# {'Unemployment rate': 7.6}

# %%
for column in mode_impute_columns:
    ds[column] = impute_na(ds, column, mode_impute_values[column])

# %% [markdown]
# ##### Outlier Engineering

# %%
outlier_columns = ['Admission grade',
       'Previous qualification',
       'Previous qualification (grade)',
       'Curricular units 1st sem (enrolled)',
       'Curricular units 1st sem (evaluations)',
       'Curricular units 1st sem (approved)',
       'Curricular units 1st sem (grade)',
       'Curricular units 1st sem (without evaluations)',
       'Curricular units 2nd sem (credited)',
       'Curricular units 2nd sem (enrolled)',
       'Curricular units 2nd sem (evaluations)',
       'Curricular units 2nd sem (approved)',
       'Curricular units 2nd sem (grade)',
       'Curricular units 2nd sem (without evaluations)']

# %%
ds = ds[(np.abs(stats.zscore(ds[outlier_columns])) < 4).all(axis=1)]

# %% [markdown]
# ##### Categorical encoding

# %%
cat_columns = ['Marital status', 'Application mode', 'Application order',
       'Course', 'Daytime/evening attendance\t', 'Previous qualification',
       'Previous qualification (grade)', 'Nacionality', 'Admission grade',
       'Displaced', 'Educational special needs', 'Debtor',
       'Tuition fees up to date', 'Gender', 'Scholarship holder',
       'Age at enrollment', 'International', 'Unemployment rate',
       'Inflation rate', 'GDP']

# %%
map_dicts = dict()
for column in cat_columns:
    ds[column] = ds[column].astype('category')
    map_dicts[column] = dict(zip(ds[column], ds[column].cat.codes))
    ds[column] = ds[column].cat.codes

# %%
display(ds.sample(15))
# Out:
#       Unnamed: 0  Marital status  Application mode  Application order  Course  \
# 1585        1585               0                 0                  0       1
# 745          745               1                11                  0       3
# 1335        1335               0                 7                  1      15
# 4079        4079               0                 0                  1      13
# 2831        2831               0                 7                  2       8
# 416          416               0                 0                  0       5
# 1751        1751               0                 0                  0      -1
# 1516        1516               0                 3                  0      11
# 3907        3907               0                 0                  0       9
# 1111        1111               0                 0                  4      11
# 1069        1069               0                 0                  1      13
# 1600        1600               0                 0                  3       1
# 3946        3946               0                 7                  1       1
# 4341        4341               0                 7                  1      11
# 1236        1236               0                 0                  5      11
#
#       Daytime/evening attendance\t  Previous qualification  \
# 1585                             1                       0
# 745                              1                       0
# 1335                             1                       0
# 4079                             1                       0
# 2831                             1                       0
# 416                              1                       0
# 1751                             1                       0
# 1516                             1                       5
# 3907                             1                       0
# 1111                             1                       0
# 1069                             1                       0
# 1600                             1                       0
# 3946                             1                       0
# 4341                             1                       0
# 1236                             1                       0
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 1585                              33            0                      29
# 745                               36            0                       1
# 1335                              36            0                       1
# 4079                              52            0                      37
# 2831                              36            0                       1
# 416                               36            0                       1
# 1751                              36            0                      38
# 1516                              36            0                      19
# 3907                              36            0                       3
# 1111                              36            0                       1
# 1069                              11            0                      19
# 1600                              34            0                       1
# 3946                              51            0                       3
# 4341                              54            0                      19
# 1236                              50            0                       1
#
#       Father's qualification  Mother's occupation  Father's occupation  \
# 1585                      38                  9.0                  8.0
# 745                        1                  4.0                  5.0
# 1335                      19                  2.0                 10.0
# 4079                      37                  9.0                  7.0
# 2831                       1                  4.0                  7.0
# 416                        1                  9.0                  9.0
# 1751                      19                  9.0                  9.0
# 1516                       1                  4.0                  1.0
# 3907                      38                  1.0                  5.0
# 1111                      19                  6.0                  7.0
# 1069                      19                  9.0                  9.0
# 1600                       1                  0.0                  3.0
# 3946                       1                  2.0                  6.0
# 4341                      37                  5.0                  9.0
# 1236                      37                  4.0                  3.0
#
#       Admission grade  Displaced  Educational special needs  Debtor  \
# 1585              215          1                          0       0
# 745               535          1                          0       0
# 1335              255          1                          0       0
# 4079              313          1                          0       0
# 2831              239          1                          0       0
# 416               269          1                          0       0
# 1751              373          1                          0       0
# 1516              395          1                          0       0
# 3907              362          1                          0       0
# 1111              150          1                          0       0
# 1069              137          1                          0       0
# 1600              482          1                          0       0
# 3946              389          1                          0       0
# 4341              300          1                          0       0
# 1236              263          1                          0       0
#
#       Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  \
# 1585                        1       1                   0                  3
# 745                         0       1                   0                 12
# 1335                        1       0                   0                  2
# 4079                        1       0                   1                  1
# 2831                        1       0                   0                  1
# 416                         1       0                   0                  2
# 1751                        1       1                   1                  2
# 1516                        0       0                   0                 22
# 3907                        1       0                   0                  5
# 1111                        1       0                   1                  2
# 1069                        1       0                   0                  1
# 1600                        1       1                   0                  1
# 3946                        1       0                   1                  1
# 4341                        1       0                   0                  1
# 1236                        1       0                   0                  1
#
#       International  Curricular units 1st sem (credited)  \
# 1585              0                                    0
# 745               0                                    0
# 1335              0                                    0
# 4079              0                                    0
# 2831              0                                    0
# 416               0                                    0
# 1751              0                                    0
# 1516              0                                    0
# 3907              0                                    0
# 1111              0                                    0
# 1069              0                                    0
# 1600              0                                    0
# 3946              0                                    0
# 4341              0                                    0
# 1236              0                                    0
#
#       Curricular units 1st sem (enrolled)  \
# 1585                             0.000000
# 745                              6.000000
# 1335                             6.000000
# 4079                             6.000000
# 2831                             5.000000
# 416                              6.000000
# 1751                             6.285986
# 1516                             7.000000
# 3907                             6.000000
# 1111                             7.000000
# 1069                             6.000000
# 1600                             0.000000
# 3946                             0.000000
# 4341                             8.000000
# 1236                             7.000000
#
#       Curricular units 1st sem (evaluations)  \
# 1585                                       0
# 745                                        6
# 1335                                       9
# 4079                                       8
# 2831                                       5
# 416                                       13
# 1751                                       0
# 1516                                       0
# 3907                                      11
# 1111                                       8
# 1069                                       9
# 1600                                       0
# 3946                                       0
# 4341                                       8
# 1236                                       7
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 1585                                  0.0                          0.000000
# 745                                   0.0                          0.000000
# 1335                                  5.0                         13.000000
# 4079                                  6.0                         13.571429
# 2831                                  5.0                         12.600000
# 416                                   6.0                         15.230769
# 1751                                  0.0                         10.635909
# 1516                                  0.0                          0.000000
# 3907                                  4.0                         12.500000
# 1111                                  7.0                         12.135714
# 1069                                  4.0                         13.200000
# 1600                                  0.0                          0.000000
# 3946                                  0.0                          0.000000
# 4341                                  7.0                         14.240000
# 1236                                  7.0                         13.442857
#
#       Curricular units 1st sem (without evaluations)  \
# 1585                                        0.000000
# 745                                         0.135172
# 1335                                        0.135172
# 4079                                        0.000000
# 2831                                        0.135172
# 416                                         0.135172
# 1751                                        0.135172
# 1516                                        0.135172
# 3907                                        0.135172
# 1111                                        0.135172
# 1069                                        0.000000
# 1600                                        0.000000
# 3946                                        0.000000
# 4341                                        0.000000
# 1236                                        0.000000
#
#       Curricular units 2nd sem (credited)  \
# 1585                             0.000000
# 745                              0.000000
# 1335                             0.000000
# 4079                             0.000000
# 2831                             0.000000
# 416                              0.000000
# 1751                             0.549845
# 1516                             0.000000
# 3907                             0.000000
# 1111                             0.000000
# 1069                             0.000000
# 1600                             0.000000
# 3946                             0.000000
# 4341                             0.000000
# 1236                             0.000000
#
#       Curricular units 2nd sem (enrolled)  \
# 1585                                  0.0
# 745                                   6.0
# 1335                                  6.0
# 4079                                  6.0
# 2831                                  5.0
# 416                                   6.0
# 1751                                  0.0
# 1516                                  8.0
# 3907                                  6.0
# 1111                                  8.0
# 1069                                  6.0
# 1600                                  0.0
# 3946                                  0.0
# 4341                                  8.0
# 1236                                  8.0
#
#       Curricular units 2nd sem (evaluations)  \
# 1585                                     0.0
# 745                                      8.0
# 1335                                     8.0
# 4079                                     6.0
# 2831                                     5.0
# 416                                     10.0
# 1751                                     0.0
# 1516                                     0.0
# 3907                                    13.0
# 1111                                    10.0
# 1069                                    10.0
# 1600                                     0.0
# 3946                                     0.0
# 4341                                     8.0
# 1236                                     9.0
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 1585                                    0                          0.000000
# 745                                     0                          0.000000
# 1335                                    5                         10.400000
# 4079                                    5                         12.800000
# 2831                                    4                         11.000000
# 416                                     6                         12.375000
# 1751                                    0                          0.000000
# 1516                                    0                          0.000000
# 3907                                    3                         13.666667
# 1111                                    7                         13.328571
# 1069                                    5                         12.800000
# 1600                                    0                          0.000000
# 3946                                    0                          0.000000
# 4341                                    7                         14.240000
# 1236                                    8                         13.744444
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 1585                                               0                  0
# 745                                                0                  8
# 1335                                               0                  0
# 4079                                               0                  5
# 2831                                               0                  4
# 416                                                0                  8
# 1751                                               0                  7
# 1516                                               0                  5
# 3907                                               0                  2
# 1111                                               0                  5
# 1069                                               0                  5
# 1600                                               0                  4
# 3946                                               0                  8
# 4341                                               0                  3
# 1236                                               0                  9
#
#       Inflation rate  GDP    Target       Citizenship Family Position  \
# 1585               7    4  Graduate            Athens     First Child
# 745                8    0   Dropout            Athens             NaN
# 1335               7    4  Enrolled          Istanbul             NaN
# 4079               3    7  Enrolled  Saint Petersburg  Youngest Child
# 2831               4    8  Enrolled          Budapest             NaN
# 416                8    0  Graduate          Brussels             NaN
# 1751               1    5  Graduate          Brussels             NaN
# 1516               3    7   Dropout              Rome             NaN
# 3907               0    1  Enrolled         Edinburgh             NaN
# 1111               3    7  Graduate          Istanbul             NaN
# 1069               3    7  Graduate            Berlin    Middle Child
# 1600               4    8  Graduate              Oslo     First Child
# 3946               8    0  Graduate         Barcelona    Middle Child
# 4341               6    6  Graduate            Berlin     First Child
# 1236               2    3  Graduate            Venice    Middle Child
#
#            Attendance Field of Study     Special Needs
# 1585  Evening Classes    Engineering  No Special Needs
# 745         Full-Time           Arts               NaN
# 1335           Online       Commerce               NaN
# 4079        Full-Time           Arts  No Special Needs
# 2831  Evening Classes        Science               NaN
# 416            Online           Arts               NaN
# 1751        Part-Time        Science               NaN
# 1516  Evening Classes       Commerce               NaN
# 3907           Online       Medicine               NaN
# 1111        Part-Time    Engineering               NaN
# 1069        Part-Time           Arts  No Special Needs
# 1600           Online       Medicine  No Special Needs
# 3946           Online       Commerce     Special Needs
# 4341           Online    Engineering     Special Needs
# 1236        Full-Time           Arts     Special Needs

# %% [markdown]
# # Model tuning

# %% [markdown]
# https://en.wikipedia.org/wiki/Hyperparameter_optimization

# %% [markdown]
# #### Parameters vs Hyperparameters
# Let’s now define what are hyperparameters, but before doing that let’s consider the difference between a parameter and a hyperparameter.
#
# A parameter can be considered to be intrinsic or internal to the model and can be obtained after the model has learned from the data.
# Examples of parameters are regression coefficients in linear regression, support vectors in support vector machines and weights in neural networks.
#
# A hyperparameter can be considered to be extrinsic or external to the model and can be set arbitrarily by the practitioner.
# Examples of hyperparameters include the k in k-nearest neighbors, number of trees and maximum number of features in random forest, learning rate and momentum in neural networks, the C and gamma parameters in support vector machines.

# %% [markdown]
# #### Hyperparameter tuning
# As there are no universal best hyperparameters to use for any given problem, hyperparameters are typically set to default values. However, the optimal set of hyperparameters can be obtained from manual empirical (trial-and-error) hyperparameter search or in an automated fashion via the use of optimization algorithm to maximize the fitness function.
#
# Two common hyperparameter tuning methods include grid search and random search. As the name implies, a grid search entails the creation of a grid of possible hyperparameter values whereby models are iteratively built for all of these hyperparameter combinations in a brute force manner. In a random search, not all hyperparameter combinations are used, but instead each iteration makes use of a random hyperparameter combination.

# %% [markdown]
# #### Define target and features columns

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4199 entries, 0 to 4423
# Data columns (total 43 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Unnamed: 0                                      4199 non-null   int64
#  1   Marital status                                  4199 non-null   int8
#  2   Application mode                                4199 non-null   int8
#  3   Application order                               4199 non-null   int8
#  4   Course                                          4199 non-null   int8
#  5   Daytime/evening attendance	                     4199 non-null   int8
#  6   Previous qualification                          4199 non-null   int8
#  7   Previous qualification (grade)                  4199 non-null   int8
#  8   Nacionality                                     4199 non-null   int8
#  9   Mother's qualification                          4199 non-null   int64
#  10  Father's qualification                          4199 non-null   int64
#  11  Mother's occupation                             3987 non-null   float64
#  12  Father's occupation                             4092 non-null   float64
#  13  Admission grade                                 4199 non-null   int16
#  14  Displaced                                       4199 non-null   int8
#  15  Educational special needs                       4199 non-null   int8
#  16  Debtor                                          4199 non-null   int8
#  17  Tuition fees up to date                         4199 non-null   int8
#  18  Gender                                          4199 non-null   int8
#  19  Scholarship holder                              4199 non-null   int8
#  20  Age at enrollment                               4199 non-null   int8
#  21  International                                   4199 non-null   int8
#  22  Curricular units 1st sem (credited)             4199 non-null   int64
#  23  Curricular units 1st sem (enrolled)             4199 non-null   float64
#  24  Curricular units 1st sem (evaluations)          4199 non-null   int64
#  25  Curricular units 1st sem (approved)             4199 non-null   float64
#  26  Curricular units 1st sem (grade)                4199 non-null   float64
#  27  Curricular units 1st sem (without evaluations)  4199 non-null   float64
#  28  Curricular units 2nd sem (credited)             4199 non-null   float64
#  29  Curricular units 2nd sem (enrolled)             4199 non-null   float64
#  30  Curricular units 2nd sem (evaluations)          4199 non-null   float64
#  31  Curricular units 2nd sem (approved)             4199 non-null   int64
#  32  Curricular units 2nd sem (grade)                4199 non-null   float64
#  33  Curricular units 2nd sem (without evaluations)  4199 non-null   int64
#  34  Unemployment rate                               4199 non-null   int8
#  35  Inflation rate                                  4199 non-null   int8
#  36  GDP                                             4199 non-null   int8
#  37  Target                                          4199 non-null   object
#  38  Citizenship                                     3753 non-null   object
#  39  Family Position                                 1955 non-null   object
#  40  Attendance                                      4199 non-null   object
#  41  Field of Study                                  4199 non-null   object
#  42  Special Needs                                   2059 non-null   object
# dtypes: float64(10), int16(1), int64(7), int8(19), object(6)
# memory usage: 873.4+ KB

# %%
y_column = ['Scholarship holder'] # target variable
X_columns = ['Marital status', 'Application mode', 'Application order',
       'Course', 'Daytime/evening attendance\t', 'Previous qualification',
       'Previous qualification (grade)', 'Nacionality',
    'Admission grade',
       'Displaced', 'Educational special needs', 'Debtor',
       'Tuition fees up to date', 'Gender', 
       'Age at enrollment', 'International',
       'Curricular units 1st sem (credited)',
       'Curricular units 1st sem (enrolled)',
       'Curricular units 1st sem (evaluations)',
       'Curricular units 1st sem (approved)',
       'Curricular units 1st sem (grade)',
       'Curricular units 1st sem (without evaluations)',
       'Curricular units 2nd sem (credited)',
       'Curricular units 2nd sem (enrolled)',
       'Curricular units 2nd sem (evaluations)',
       'Curricular units 2nd sem (approved)',
       'Curricular units 2nd sem (grade)',
       'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
       'Inflation rate', 'GDP']
X = ds[X_columns]
y = ds[y_column]

# %%
# Let's say we want to split the data in 80:10:10 for train:valid:test dataset
# In the first step we will split the data in training and remaining dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3359, 31)
# (3359, 1)
# (840, 31)
# (840, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
y_pred = dt_classifier.predict(X_test)
metrics.precision_score(y_test, y_pred)
# Out:
# 0.3349282296650718

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import recall_score
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
y_pred = dt_classifier.predict(X_test)
metrics.recall_score(y_test, y_pred)
# Out:
# 0.3150684931506849

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
y_pred = dt_classifier.predict(X_test)
metrics.f1_score(y_test, y_pred)
# Out:
# 0.3023255813953488

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
y_pred = dt_classifier.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.6523809523809524

# %%
from sklearn.naive_bayes import GaussianNB 
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import classification_report
# Створюємо модель класифікатора
gnb = GaussianNB()
# Оголошуємо простір гіперпараметрів для перебору
param_grid = {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5],
    'priors': [None, [0.3, 0.7], [0.5, 0.5], [0.7, 0.3]]
}

# Оголошуємо метрики, які будемо використовувати для оцінки
scoring = {'accuracy':'accuracy', 'recall':'recall', 'f1': 'f1'}
# Створюємо обʼєкт GridSearchCV
grid_search = GridSearchCV(estimator=gnb, param_grid=param_grid, scoring=scoring, refit='f1', cv=5)
# Виконуємо пошук найкращих параметрів
grid_search.fit(X_train, y_train)
# Отримуємо найкращі параметри та модель
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
# Прогнозуємо на тестових даних
y_pred = best_model.predict(X_test)
# Виводимо звіт метрик класифікації
print('Test set metrics:')
print(classification_report(y_test, y_pred))
# Out:
# Test set metrics:
#               precision    recall  f1-score   support
#
#            0       0.82      0.50      0.62       621
#            1       0.33      0.70      0.45       219
#
#     accuracy                           0.55       840
#    macro avg       0.58      0.60      0.53       840
# weighted avg       0.69      0.55      0.57       840

# %%
from sklearn.naive_bayes import GaussianNB 
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
# Створюємо модель класифікатора
gnb = GaussianNB()
# Оголошуємо простір гіперпараметрів для перебору
param_grid = {
    'var_smoothing': uniform(loc=1e-9, scale=1e-5),
    'priors': [None, [0.3, 0.7], [0.5, 0.5], [0.7, 0.3]]
}

# Оголошуємо метрики, які будемо використовувати для оцінки
scoring = {'accuracy':'accuracy', 'recall':'recall', 'f1': 'f1'}
# Створюємо обʼєкт GridSearchCV
grid_search = RandomizedSearchCV(estimator=gnb, param_distributions=param_grid, scoring=scoring, refit='f1', cv=5)
# Виконуємо пошук найкращих параметрів
grid_search.fit(X_train, y_train)
# Отримуємо найкращі параметри та модель
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
# Прогнозуємо на тестових даних
y_pred = best_model.predict(X_test)
# Виводимо звіт метрик класифікації
print('Test set metrics:')
print(classification_report(y_test, y_pred))
# Out:
# Test set metrics:
#               precision    recall  f1-score   support
#
#            0       0.83      0.49      0.62       621
#            1       0.33      0.72      0.45       219
#
#     accuracy                           0.55       840
#    macro avg       0.58      0.60      0.54       840
# weighted avg       0.70      0.55      0.58       840

# %% [markdown]
# #### Building a Baseline Random Forest Model
# Here, we will first start by building a baseline random forest model that will serve as a baseline for comparative purpose with the model using the optimal set of hyperparameters.
# For the baseline model, we will set an arbitrary number for the 2 hyperparameters (e.g. n_estimators and max_features) that we will also use in the next section for hyperparameter tuning.

# %%
rf = RandomForestClassifier(max_features=5, n_estimators=100)

# %%
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
print('test set metrics: ', metrics.classification_report(y_test, y_pred))
# Out:
# test set metrics:                precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84       621
#            1       0.49      0.18      0.27       219
#
#     accuracy                           0.74       840
#    macro avg       0.63      0.56      0.55       840
# weighted avg       0.69      0.74      0.69       840

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 5,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #### Hyperparameter Tuning
# Now we will be performing the tuning of hyperparameters of the random forest model.

# %% [markdown]
# n_estimators = number of trees in the foreset
#
# max_features = max number of features considered for splitting a node
#
# max_depth = max number of levels in each decision tree
#
# min_samples_split = min number of data points placed in a node before the node is split
#
# min_samples_leaf = min number of data points allowed in a leaf node
#
# bootstrap = method for sampling data points (with or without replacement)

# %% [markdown]
# https://towardsdatascience.com/hyperparameter-tuning-always-tune-your-models-7db7aeaf47e9

# %%
# %%time
# Create the random grid
param_grid = {'n_estimators': np.arange(25,55,10),
               'max_features': [0.5, 0.6, 0.8],
               'min_samples_split': [10,15],
               'min_samples_leaf': [3,4],
               'bootstrap': [False]}

# print(random_grid)


rf = RandomForestClassifier()

grid = GridSearchCV(estimator=rf, 
                    param_grid=param_grid, 
                    scoring='precision', 
                    cv=5,
                    verbose = 3,
                    return_train_score=True)

grid.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.380) total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.460) total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.995, test=0.465) total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.995, test=0.460) total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.997, test=0.509) total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.389) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.530) total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.482) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.997, test=0.491) total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.482) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.997, test=0.414) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.522) total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.506) total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.995, test=0.514) total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.455) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.985, test=0.411) total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.995, test=0.521) total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.992, test=0.489) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.991, test=0.495) total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.991, test=0.491) total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.993, test=0.415) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.995, test=0.526) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.990, test=0.481) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.983, test=0.549) total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.995, test=0.500) total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.990, test=0.393) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.997, test=0.519) total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.993, test=0.474) total time=   0.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.991, test=0.500) total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.995, test=0.516) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.995, test=0.417) total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.995, test=0.561) total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.449) total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.994, test=0.495) total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.997, test=0.455) total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.997, test=0.395) total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.515) total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.511) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=1.000, test=0.514) total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.491) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.997, test=0.394) total time=   0.7s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.560) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.506) total time=   0.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.995, test=0.491) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.995, test=0.481) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.976, test=0.421) total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.989, test=0.495) total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.993, test=0.500) total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.980, test=0.495) total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.987, test=0.504) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.987, test=0.431) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.993, test=0.551) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.984, test=0.488) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.987, test=0.495) total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.989, test=0.505) total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.989, test=0.409) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.991, test=0.500) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.988, test=0.481) total time=   0.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.990, test=0.515) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.989, test=0.500) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.443) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.994, test=0.438) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.461) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.994, test=0.510) total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.998, test=0.500) total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.997, test=0.403) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.495) total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.465) total time=   0.5s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.997, test=0.463) total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.508) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.377) total time=   0.7s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.505) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=1.000, test=0.409) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.509) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.491) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.982, test=0.415) total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.991, test=0.521) total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.992, test=0.468) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.987, test=0.500) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.990, test=0.483) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.983, test=0.402) total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.511) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.985, test=0.405) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.992, test=0.505) total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.988, test=0.448) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.986, test=0.397) total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.993, test=0.505) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.993, test=0.494) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.985, test=0.505) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.993, test=0.466) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.997, test=0.372) total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.992, test=0.460) total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.994, test=0.475) total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.995, test=0.491) total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.992, test=0.500) total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.994, test=0.409) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.997, test=0.489) total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.998, test=0.460) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.995, test=0.533) total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.997, test=0.477) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.997, test=0.383) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.997, test=0.537) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.494) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.994, test=0.536) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.998, test=0.505) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.972, test=0.440) total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.988, test=0.545) total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.988, test=0.506) total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.984, test=0.486) total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.988, test=0.519) total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.977, test=0.429) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.997, test=0.525) total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.995, test=0.463) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.993, test=0.529) total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.987, test=0.482) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.976, test=0.433) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.991, test=0.589) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.993, test=0.449) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.986, test=0.505) total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.995, test=0.531) total time=   0.7s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.986, test=0.374) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.991, test=0.432) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.994, test=0.430) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.989, test=0.500) total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=25;, score=(train=0.994, test=0.489) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.984, test=0.380) total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.986, test=0.500) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.995, test=0.451) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.987, test=0.469) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=35;, score=(train=0.994, test=0.497) total time=   0.8s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.992, test=0.381) total time=   0.7s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.991, test=0.487) total time=   0.8s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.994, test=0.469) total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.992, test=0.491) total time=   0.8s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=10, n_estimators=45;, score=(train=0.997, test=0.466) total time=   0.8s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.971, test=0.407) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.986, test=0.464) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.986, test=0.465) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.974, test=0.477) total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=25;, score=(train=0.976, test=0.500) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.970, test=0.378) total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.978, test=0.504) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.988, test=0.450) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.980, test=0.453) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=35;, score=(train=0.979, test=0.489) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.973, test=0.388) total time=   0.8s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.973, test=0.486) total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.974, test=0.463) total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.981, test=0.478) total time=   0.7s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=45;, score=(train=0.976, test=0.459) total time=   0.9s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.976, test=0.399) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.992, test=0.514) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.992, test=0.466) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.989, test=0.464) total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=25;, score=(train=0.982, test=0.458) total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.978, test=0.376) total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.989, test=0.496) total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.992, test=0.435) total time=   0.7s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.989, test=0.510) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=35;, score=(train=0.987, test=0.474) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.981, test=0.397) total time=   0.8s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.989, test=0.487) total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.994, test=0.412) total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.988, test=0.444) total time=   0.8s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=45;, score=(train=0.990, test=0.496) total time=   0.8s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.949, test=0.405) total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.973, test=0.523) total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.981, test=0.423) total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.977, test=0.477) total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=25;, score=(train=0.967, test=0.472) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.954, test=0.397) total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.977, test=0.500) total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.983, test=0.435) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.977, test=0.500) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=35;, score=(train=0.974, test=0.496) total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.957, test=0.386) total time=   0.7s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.979, test=0.495) total time=   0.8s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.976, test=0.434) total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.973, test=0.470) total time=   0.7s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=45;, score=(train=0.972, test=0.511) total time=   0.8s
# The best parameters are {'bootstrap': False, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 15, 'n_estimators': 45} with a score of 0.50
# CPU times: total: 49.6 s
# Wall time: 1min 47s

# %%
grid_results = pd.concat([pd.DataFrame(grid.cv_results_["params"]),
                          pd.DataFrame(grid.cv_results_["mean_test_score"], 
                          columns=["precision"])],
                          axis=1)

grid_results
# Out:
#     bootstrap  max_features  min_samples_leaf  min_samples_split  \
# 0       False           0.5                 3                 10
# 1       False           0.5                 3                 10
# 2       False           0.5                 3                 10
# 3       False           0.5                 3                 15
# 4       False           0.5                 3                 15
# 5       False           0.5                 3                 15
# 6       False           0.5                 4                 10
# 7       False           0.5                 4                 10
# 8       False           0.5                 4                 10
# 9       False           0.5                 4                 15
# 10      False           0.5                 4                 15
# 11      False           0.5                 4                 15
# 12      False           0.6                 3                 10
# 13      False           0.6                 3                 10
# 14      False           0.6                 3                 10
# 15      False           0.6                 3                 15
# 16      False           0.6                 3                 15
# 17      False           0.6                 3                 15
# 18      False           0.6                 4                 10
# 19      False           0.6                 4                 10
# 20      False           0.6                 4                 10
# 21      False           0.6                 4                 15
# 22      False           0.6                 4                 15
# 23      False           0.6                 4                 15
# 24      False           0.8                 3                 10
# 25      False           0.8                 3                 10
# 26      False           0.8                 3                 10
# 27      False           0.8                 3                 15
# 28      False           0.8                 3                 15
# 29      False           0.8                 3                 15
# 30      False           0.8                 4                 10
# 31      False           0.8                 4                 10
# 32      False           0.8                 4                 10
# 33      False           0.8                 4                 15
# 34      False           0.8                 4                 15
# 35      False           0.8                 4                 15
#
#     n_estimators  precision
# 0             25   0.454778
# 1             35   0.474705
# 2             45   0.482185
# 3             25   0.481301
# 4             35   0.494113
# 5             45   0.480504
# 6             25   0.475348
# 7             35   0.485283
# 8             45   0.486330
# 9             25   0.482868
# 10            35   0.493868
# 11            45   0.480948
# 12            25   0.470202
# 13            35   0.466781
# 14            45   0.458149
# 15            25   0.477375
# 16            35   0.454128
# 17            45   0.473269
# 18            25   0.459667
# 19            35   0.473760
# 20            45   0.490919
# 21            25   0.499283
# 22            35   0.485576
# 23            45   0.501327
# 24            25   0.445087
# 25            35   0.459358
# 26            45   0.458894
# 27            25   0.462640
# 28            35   0.454791
# 29            45   0.454830
# 30            25   0.459925
# 31            35   0.457989
# 32            45   0.447287
# 33            25   0.460026
# 34            35   0.465594
# 35            45   0.459336

# %%
grid_results.columns
# Out:
# Index(['bootstrap', 'max_features', 'min_samples_leaf', 'min_samples_split',
#        'n_estimators', 'precision'],
#       dtype='object')

# %%
grid_contour = grid_results.groupby([  'max_features', 'min_samples_leaf',
       'min_samples_split', 'n_estimators']).mean()
grid_contour
# Out:
#                                                               bootstrap  \
# max_features min_samples_leaf min_samples_split n_estimators
# 0.5          3                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#              4                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
# 0.6          3                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#              4                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
# 0.8          3                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#              4                10                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#                               15                25                  0.0
#                                                 35                  0.0
#                                                 45                  0.0
#
#                                                               precision
# max_features min_samples_leaf min_samples_split n_estimators
# 0.5          3                10                25             0.500409
#                                                 35             0.509282
#                                                 45             0.523058
#                               15                25             0.499740
#                                                 35             0.499457
#                                                 45             0.516006
#              4                10                25             0.498440
#                                                 35             0.516017
#                                                 45             0.517900
#                               15                25             0.511928
#                                                 35             0.523562
#                                                 45             0.532116
# 0.6          3                10                25             0.494649
#                                                 35             0.500389
#                                                 45             0.507257
#                               15                25             0.490491
#                                                 35             0.499840
#                                                 45             0.508984
#              4                10                25             0.484700
#                                                 35             0.502302
#                                                 45             0.503399
#                               15                25             0.498156
#                                                 35             0.510184
#                                                 45             0.516567
# 0.8          3                10                25             0.454833
#                                                 35             0.461177
#                                                 45             0.472321
#                               15                25             0.465636
#                                                 35             0.474251
#                                                 45             0.473806
#              4                10                25             0.459600
#                                                 35             0.466359
#                                                 45             0.467395
#                               15                25             0.467635
#                                                 35             0.477657
#                                                 45             0.483768
